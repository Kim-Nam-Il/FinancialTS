# %% [markdown]
# # Chapter 1 Exercise 2

# %% [markdown]
# file : [m-gm3dx7508.txt](https://faculty.chicagobooth.edu/-/media/faculty/ruey-s-tsay/teaching/fts3/m-gm3dx7508.txt)
#
# Page 24 Exercise 2

# %% [markdown]
# ## 1.2 Example

# %% [markdown]
# ### Load data
#
# open the data file 'm-gm3dx7508.txt' as data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# Load data
data = pd.read_csv("m-gm3dx7508.txt", delim_whitespace=True, index_col = 0)

# %%
data
# Out:
#                 gm        vw        ew        sp
# date
# 19750131  0.252033  0.141600  0.299260  0.122812
# 19750228  0.028571  0.058411  0.053918  0.059886
# 19750331  0.054487  0.030191  0.081497  0.021694
# 19750430  0.045593  0.046497  0.031093  0.047265
# 19750530  0.037209  0.055140  0.072876  0.044101
# ...            ...       ...       ...       ...
# 20080829 -0.096658  0.011042  0.014066  0.012191
# 20080930 -0.055000 -0.098060 -0.120888 -0.090791
# 20081031 -0.387302 -0.184726 -0.206004 -0.169425
# 20081128 -0.094991 -0.085206 -0.136597 -0.074849
# 20081231 -0.389313  0.021482  0.043083  0.007822
#
# [408 rows x 4 columns]

# %% [markdown]
# ### Extract GM stock returns (it's in the second column)

# %%
gm = data.iloc[:,1]
gm
# Out:
# date
# 19750131    0.141600
# 19750228    0.058411
# 19750331    0.030191
# 19750430    0.046497
# 19750530    0.055140
#               ...
# 20080829    0.011042
# 20080930   -0.098060
# 20081031   -0.184726
# 20081128   -0.085206
# 20081231    0.021482
# Name: vw, Length: 408, dtype: float64

# %% [markdown]
# ### Create a time series object (Pandas Series with a DateTime index)
#
# The data is monthly and starts from January 1975

# %%
gm1 = pd.Series(gm.values, index=pd.date_range(start='1975-01-01', periods=len(gm), freq='M'))

# %%
gm1
# Out:
# 1975-01-31    0.141600
# 1975-02-28    0.058411
# 1975-03-31    0.030191
# 1975-04-30    0.046497
# 1975-05-31    0.055140
#                 ...
# 2008-08-31    0.011042
# 2008-09-30   -0.098060
# 2008-10-31   -0.184726
# 2008-11-30   -0.085206
# 2008-12-31    0.021482
# Freq: M, Length: 408, dtype: float64

# %% [markdown]
# ### Plotting the data

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(gm, linestyle='-', marker='None')
plt.title("GM Stock Returns (Original)")

plt.subplot(2, 1, 2)
plt.plot(gm1, linestyle='-', marker='None')
plt.title("GM Stock Returns (Time Series)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotting ACF

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plot_acf(gm, lags=24, ax=plt.gca())
plt.title("Autocorrelation Function (Original)")

plt.subplot(2, 1, 2)
plot_acf(gm1, lags=24, ax=plt.gca())
plt.title("Autocorrelation Function (Time Series)")

plt.tight_layout()
plt.show()
